# %% [markdown]
# ## Calculating cost with gradient descent and learning rate
# - Change the iteration and learning rate vaules and see the impact on cost.
# - Low iteration values with high learning rate (i.e. big steps) may lead to miss the global minimum
# - Goal is to reach minimum cost with minimum iteration

# %% [markdown]
# ![cost_function.png](attachment:cost_function.png)

# %%
# code credit:codebasics https://codebasics.io/coming-soon

import numpy as np

def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 100       #change value
    n = len(x)
    learning_rate = 0.08   #change value

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0 iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002 iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001 iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613 iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832 iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282 iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438 iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738 iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156 iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794 iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109 iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315 iteration 11
# ...

# %% [markdown]
# **Comment: We see that costs are driven further down with each iteration. We also see that the steps in which the costs decrease also decreases over time, i.e., at the beginning rather big steps are made and in the end these steps get smaller. After 99 iterations, we have a cost of about 0.0041.**

# %% [markdown]
# ## My own changes:

# %% [markdown]
# First I increase the iterations:

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 200       #changed value from 100 (base line) to 200
    n = len(x)
    learning_rate = 0.08

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0 iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002 iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001 iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613 iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832 iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282 iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438 iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738 iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156 iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794 iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109 iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315 iteration 11
# ...

# %% [markdown]
# **Comment: We see that increasing the number of iterations further decreases the costs after all iterations are done.**

# %% [markdown]
# Next, I re-use the base line number for iterations and now decrease the learning rate:

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 100       # base line
    n = len(x)
    learning_rate = 0.01   # changed from the base line of 0.08 to 0.01

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 0.62, b 0.18, cost 89.0 iteration 0
# m 1.0928, b 0.3192, cost 52.25039999999999 iteration 1
# m 1.453232, b 0.42724799999999996, cost 30.831949440000002 iteration 2
# m 1.7278860800000002, b 0.5115091199999999, cost 18.347751350784 iteration 3
# m 1.9370605952000002, b 0.5776057727999999, cost 11.070010749324897 iteration 4
# m 2.096250917888, b 0.6298300216319999, cost 6.826353152519786 iteration 5
# m 2.2172859146547204, b 0.6714583661260799, cost 4.350826141683065 iteration 6
# m 2.309195511463117, b 0.7049920439242751, cost 2.9056952040975976 iteration 7
# m 2.3788729763057748, b 0.7323404723580026, cost 2.0610450731046615 iteration 8
# m 2.431580493177024, b 0.7549612843324961, cost 1.5663423003130599 iteration 9
# m 2.471335107618129, b 0.7739672290552247, cost 1.2755882811903883 iteration 10
# m 2.501203350198827, b 0.7902077780170325, cost 1.1037021437989751 iteration 11
# m 2.523526146474063, b 0.8043314214447622, cost 1.0011028556851886 iteration 12
# ...

# %% [markdown]
# **Comment: We here see that the resulting cost after 99 iterations is significantly higher than with a learning rate of 0.08. This is the case because smaller steps are made in adjusting the weights.**
#
# **But what happens when we use the learning rate of 0.01 and the increased number of iterations (200)?**

# %% [markdown]
# Next, I check how a smaller learning rate of 0.01 works together with a higher number of iterations of 200:

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 200       # changed from the base line of 100 to 200
    n = len(x)
    learning_rate = 0.01   # changed from the base line of 0.08 to 0.01

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 0.62, b 0.18, cost 89.0 iteration 0
# m 1.0928, b 0.3192, cost 52.25039999999999 iteration 1
# m 1.453232, b 0.42724799999999996, cost 30.831949440000002 iteration 2
# m 1.7278860800000002, b 0.5115091199999999, cost 18.347751350784 iteration 3
# m 1.9370605952000002, b 0.5776057727999999, cost 11.070010749324897 iteration 4
# m 2.096250917888, b 0.6298300216319999, cost 6.826353152519786 iteration 5
# m 2.2172859146547204, b 0.6714583661260799, cost 4.350826141683065 iteration 6
# m 2.309195511463117, b 0.7049920439242751, cost 2.9056952040975976 iteration 7
# m 2.3788729763057748, b 0.7323404723580026, cost 2.0610450731046615 iteration 8
# m 2.431580493177024, b 0.7549612843324961, cost 1.5663423003130599 iteration 9
# m 2.471335107618129, b 0.7739672290552247, cost 1.2755882811903883 iteration 10
# m 2.501203350198827, b 0.7902077780170325, cost 1.1037021437989751 iteration 11
# m 2.523526146474063, b 0.8043314214447622, cost 1.0011028556851886 iteration 12
# ...

# %% [markdown]
# **Comment: We see that the resulting costs are still a lot higher than with a greater learning rate of 0.08. I now need to check how this changes for extremely high numbers of iterations.**

# %% [markdown]
# Next I compare the resulting costs for learning rates of 0.01 and 0.08, each with 1,000 iterations.

# %% [markdown]
# Learning rate of 0.08 and 1,000 iterations:

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 1000
    n = len(x)
    learning_rate = 0.08

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0 iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002 iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001 iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613 iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832 iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282 iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438 iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738 iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156 iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794 iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109 iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315 iteration 11
# ...

# %% [markdown]
# Learning rate of 0.01 and 1,000 iterations:

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 1000
    n = len(x)
    learning_rate = 0.01

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 0.62, b 0.18, cost 89.0 iteration 0
# m 1.0928, b 0.3192, cost 52.25039999999999 iteration 1
# m 1.453232, b 0.42724799999999996, cost 30.831949440000002 iteration 2
# m 1.7278860800000002, b 0.5115091199999999, cost 18.347751350784 iteration 3
# m 1.9370605952000002, b 0.5776057727999999, cost 11.070010749324897 iteration 4
# m 2.096250917888, b 0.6298300216319999, cost 6.826353152519786 iteration 5
# m 2.2172859146547204, b 0.6714583661260799, cost 4.350826141683065 iteration 6
# m 2.309195511463117, b 0.7049920439242751, cost 2.9056952040975976 iteration 7
# m 2.3788729763057748, b 0.7323404723580026, cost 2.0610450731046615 iteration 8
# m 2.431580493177024, b 0.7549612843324961, cost 1.5663423003130599 iteration 9
# m 2.471335107618129, b 0.7739672290552247, cost 1.2755882811903883 iteration 10
# m 2.501203350198827, b 0.7902077780170325, cost 1.1037021437989751 iteration 11
# m 2.523526146474063, b 0.8043314214447622, cost 1.0011028556851886 iteration 12
# ...

# %% [markdown]
# **Comment: We see that the result still remains that the higher learning rate is associated with a lower resulting cost.**
#
# **But the goal remains to set the number of iterations as low as possible and set a learning rate that leads to minimal costs.**

# %% [markdown]
# In the last run of the code I thus aim at setting learning rate and iterations to minimise costs for a rather low number of iterations:

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 50
    n = len(x)
    learning_rate = 0.08

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 4.96, b 1.44, cost 89.0 iteration 0
# m 0.4991999999999983, b 0.26879999999999993, cost 71.10560000000002 iteration 1
# m 4.451584000000002, b 1.426176000000001, cost 56.8297702400001 iteration 2
# m 0.892231679999997, b 0.5012275199999995, cost 45.43965675929613 iteration 3
# m 4.041314713600002, b 1.432759910400001, cost 36.35088701894832 iteration 4
# m 1.2008760606719973, b 0.7036872622079998, cost 29.097483330142282 iteration 5
# m 3.7095643080294423, b 1.4546767911321612, cost 23.307872849944438 iteration 6
# m 1.4424862661541864, b 0.881337636696883, cost 18.685758762535738 iteration 7
# m 3.4406683721083144, b 1.4879302070713722, cost 14.994867596913156 iteration 8
# m 1.6308855378034224, b 1.0383405553279617, cost 12.046787238456794 iteration 9
# m 3.2221235247119777, b 1.5293810083298451, cost 9.691269350698109 iteration 10
# m 1.7770832372205707, b 1.1780607551353204, cost 7.8084968312098315 iteration 11
# ...

# %% [markdown]
# **We see that for only 50 iterations we are able to decrease the cost to a very small level with a learning rate of 0.08. We also see that the cost still decreases with each iteration which shows that the learning rate was not set too great.**

# %% [markdown]
# We see that increasing the learning rate to 0.081 increases the resulting cost:

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 50
    n = len(x)
    learning_rate = 0.081

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 5.022, b 1.458, cost 89.0 iteration 0
# m 0.3862079999999999, b 0.239112, cost 74.87554399999999 iteration 1
# m 4.603776912, b 1.470678768, cost 63.00306716422401 iteration 2
# m 0.7070965735680002, b 0.45299322835199995, cost 53.02295182327482 iteration 3
# m 4.248895770490753, b 1.493959390604928, cost 44.63303815895167 iteration 4
# m 0.9732992436422356, b 0.6449746248684235, cost 37.579442229054905 iteration 5
# m 3.9474223237857187, b 1.5254653032296126, cost 31.64884139501119 iteration 6
# m 1.1937396054299763, b 0.817892674746556, cost 26.66199263682485 iteration 7
# m 3.6909997886269323, b 1.5632366131986457, cost 22.46828671961694 iteration 8
# m 1.3759051712791965, b 0.9741663845877759, cost 18.941172665824503 iteration 9
# m 3.472597293150009, b 1.6056615170428667, cost 15.974313444295928 iteration 10
# m 1.5260774194738602, b 1.115862066811018, cost 13.478356016349876 iteration 11
# m 3.2862984935012864, b 1.6514187861233371, cost 11.378217555124417 iteration 12
# ...

# %% [markdown]
# The effect of a too great learning rate with a rather small number of iterations is that the local minimum is missed:

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 50
    n = len(x)
    learning_rate = 5

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

gradient_descent(x,y)
# Out:
# m 310.0, b 90.0, cost 89.0 iteration 0
# m -36180.0, b -10020.0, cost 1211849.0 iteration 1
# m 4244530.0, b 1175670.0, cost 16676882009.0 iteration 2
# m -497923560.0, b -137916840.0, cost 229499299266569.0 iteration 3
# m 58411173550.0, b 16178958450.0, cost 3.158259939483662e+18 iteration 4
# m -6852186670140.0, b -1897945832460.0, cost 4.346246754227167e+22 iteration 5
# m 803826722019370.0, b 222647112596430.0, cost 5.981097569732797e+26 iteration 6
# m -9.429652607800392e+16, b -2.611862567394889e+16, cost 8.23090131821673e+30 iteration 7
# m 1.1061880112720894e+19, b 3.0639634134056576e+18, cost 1.1326973974318312e+35 iteration 8
# m -1.2976638346887472e+21, b -3.5943207410227773e+20, cost 1.5587641554021373e+39 iteration 9
# m 1.5222832020414177e+23, b 4.216480370758292e+22, cost 2.1450969143881763e+43 iteration 10
# m -1.7857831013478942e+25, b -4.9463328394925e+24, cost 2.9519801030647717e+47 iteration 11
# ...

# %% [markdown]
# **Here, we see that the cost increases between certain iteration. This is the case because of very extreme changes in the values due to the great learning rate.**

# %% [markdown]
# ## Overall Observations:

# %% [markdown]
# **Overall, through all the changes made to the learning rate and number of iterations, we see that for a very high number of iterations it is easy to find small costs. For smaller numbers of iterations, which are preferred, it is not that easy anymore. Important is to find a learning rate for which the costs decrease with every iteration. This means that the learning rate is not noo great. Then, the learning rate is increased slightly multiple times to finally get the learning rate that works best for the given number of iterations.**
#
# **Typically, then one would also try to change the number of iterations. For an even smaller number of iterations, the learning rate would then need to be further decreased. This process then shows which costs are achievable at different numbers of iterations. Then, a decision on how many iterations are acceptable would need to be made.**
